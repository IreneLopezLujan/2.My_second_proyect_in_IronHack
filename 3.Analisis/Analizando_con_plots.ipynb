# %% [markdown]
# #       🍀🍀🍀🍀🥔                # ANALISIS#             🍀🍀🍀🥔

# %%
from IPython.display import Image
import pandas as pd

# %% [markdown]
# ## ¿Cuantos días laborales llueve y nos mojaremos ?

# %%
os.chdir("../plots")
Image(filename = "infog1.png", width = 800, height = 200)

# %%
En Dublín llueve todos los meses.Estamos preocupados acerca del peligro de mover la furgo cuando llueve. Lafurgo la movemos al ir a abrir el puesto po la mañana
y por la noche. Si coincide que es dia labora y trabajamos y que llueve justo en mañana o tarde, podriamos tener un accidente
 principalmente destacamos Enero Marzo y Mayo. Nos replantearemos en dicho caso no movilizar el Food track 
para no tener

# %%
os.chdir("../data")
pd.read_csv("table1.1.csv", engine = "c")
# Out:
#    get_wet_cycling  day
# 0             True  883

# %% [markdown]
# Especificamente en los dos ultimos años nos hubieramos mojado 883 días...casi todos....mejor estarnos quietos

# %% [markdown]
# ## ¿Cuantos días llueve en Dublin?¿Por meses?¿Por días?¿Por horas?

# %%
os.chdir("../plots")
Image(filename = "infog2.png", width = 800, height = 200)

# %% [markdown]
# Con esta gráfica vemos la distribución de lluvias, en todas las horas  sea dia laboral o no. Vemos que el dia de la semana como es obvio, no influye en las lluvias.
# Pero existe un mapa muy colorido...Si, en Dublín llueve bastante y coincide con los meses anteriores.
# Esta claro que necesitaremos una foodtrack con techo y carpa para los clientes.

# %% [markdown]
# ## ¿Qué tipos de restaurantes hay más en Dublín?

# %%
os.chdir("../plots")
Image(filename = "infog3.png", width = 800, height = 200)

# %% [markdown]
# Dentro de los tipos de restaurantes por nacionalidad en Dublín,
# los españoles son los que mas hay en tercer lugar.
# Podríamos pensar que les gustan mucho este tipo de restaurantes y es una oportunidad, o que por el contrario haymucha competencia.
# Lo dejamos a futuras lineas de investigación.

# %% [markdown]
# # #¿Como va el empleo por sector?

# %%
os.chdir("../plots")
Image(filename = "infog4.png", width = 800, height = 200)
#NO HE CONSEGUIDO CAMBIAR LOS STICKS DE LA X

# %% [markdown]
# De la parcela se puede concluir que el empleo en la localidad muestra una tendencia al alza especialmente desde el sector privado y las actividades sociales y de salud humana. Esto lleva a la conclusión de que la población de Dublín está creciendo, por lo que la venta del tortilla de patatas es factible en Dublín debido al crecimiento de la población.

# %% [markdown]
# ## Densidad de poblacion por calle ¿Dónde ponemos el puesto?

# %%
os.chdir("../plots")
Image(filename = "infog5.png", width = 900, height = 500)

# %% [markdown]
# En este grafico vemos el trafico de viandantes por calles segun días de la semana. Por un lado comprobamos que en general cuando mas gente hay en casi todas las calles son los Martes y los Viernes.
# Entre las calles más transcurridas son Henry Street, Grafton Street, Talbot Street, Lifey Street, Dawson Street, Oconell Parnell...

# %% [markdown]
# ## Valoracion por calle

# %%
os.chdir("../data")
pd.read_csv("table2.csv", engine = "c")
# Out:
#     Unnamed: 0                                     Locations  valoration  \
# 0            8                               Mountjoy Square           5
# 1            9                                  Meath Street           5
# 2           10                                Thomas Street            5
# 3            5  Corner of Parnell & Nth Great Georges Street           4
# 4            6                                 Camden Street           4
# 5            7                                Francis Street           4
# 6            2                                Aungier Street           3
# 7            3                                  Manor Street           3
# 8            4                                    Ellis Quay           3
# 9            1                                    Arran Quay           2
# 10           0                       Abbey Street (Luas end)           1
#
#                  What people like about this location  \
# ...

# %% [markdown]
# Aunque faltarían más calles por valorar y que nos hubiera venido genial que metieran en la encuesta, vamos a analizar de esta muestra los mas valorados y comprobar si coinciden los de mayor valor con alguna de las calles más transcurridas. Parece Que Thomas Street con valoracion 5 se encuentra cerca de las zonas más transcurridas aunque no aparezca en la lista de densidad y Parnell con valoracion 4 puede ser otra opcion que coincide con una de las calles más transcurridas, Occonel Parnell
